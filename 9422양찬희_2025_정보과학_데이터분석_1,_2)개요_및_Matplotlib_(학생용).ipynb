# %% [markdown]
# <a href="https://colab.research.google.com/github/lolpopa360/lolpopa/blob/main/9422%EC%96%91%EC%B0%AC%ED%9D%AC_2025_%EC%A0%95%EB%B3%B4%EA%B3%BC%ED%95%99_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_1%2C_2)%EA%B0%9C%EC%9A%94_%EB%B0%8F_Matplotlib_(%ED%95%99%EC%83%9D%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 1차시: 데이터 분석 개요

# %% [markdown]
# ## 🔷 학습 목표
# - 데이터 분석의 정의와 필요성을 이해한다.
# - 데이터 분석의 전체 과정을 설명할 수 있다.
# - 간단한 데이터를 해석하고 시각화할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 📌 데이터(data)와 정보(information)의 차이
#
# | 구분 | 데이터 (Data) | 정보 (Information) |
# |------|----------------|---------------------|
# | 정의 | 사실이나 수치, 관찰 결과 등 가공되지 않은 값 | 데이터를 정리하고 해석하여 의미 있는 형태로 만든 것 |
# | 예시 | '90, 85, 72' (점수만 있음) | '이 학생의 평균 점수는 82.3점이다' (해석이 들어감) |
# | 특징 | 가공되지 않은 상태 | 분석, 요약, 해석이 포함됨 |
# | 역할 | 정보의 **재료** | 의사결정에 활용되는 **도구** |
#
# 👉 즉, **데이터는 원재료**, **정보는 가공된 결과물**이라고 볼 수 있어요.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🔺 DIKW 피라미드란?
#
# DIKW 피라미드는 데이터를 기반으로 **정보 → 지식 → 지혜**로 발전해가는 구조를 설명하는 모델입니다.
#
# | 단계 | 설명 | 예시 |
# |------|------|------|
# | **Data (데이터)** | 단순한 사실, 숫자 | '82, 75, 90' (시험 점수만 있음) |
# | **Information (정보)** | 데이터를 해석해 의미를 부여 | '이 학생의 평균은 82.3점이다' |
# | **Knowledge (지식)** | 정보 간의 관계와 패턴 | '이 학생은 수학보다 영어 성적이 높다' |
# | **Wisdom (지혜)** | 경험과 통찰을 통한 판단 | '영어는 잘하지만 수학 보충이 필요하겠다' |
#
# 이 구조는 단순한 데이터 수집이 아닌, **실제로 어떤 결정을 내릴 수 있는 수준까지 분석하는 과정**을 보여줍니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ✨ 실생활에서 데이터가 중요한 이유
#
# - 유튜브: 어떤 영상을 추천할지 결정할 때 시청 기록 데이터 분석!
# - 날씨 예보: 과거 기온, 습도 데이터를 바탕으로 오늘 날씨 예측!
# - 스포츠: 선수의 경기 기록 데이터를 분석해서 전략을 짬!
# - 쇼핑몰: 어떤 상품이 인기가 많은지 구매 데이터를 분석해서 마케팅!
#
# ### ✔ 데이터가 없으면?
# - 감에 의존한 판단 → 실수나 손실 가능성 증가
# - 근거 없는 결론 → 신뢰도 낮아짐

# %% [markdown]
# ## 🧠 데이터 분석이란?
#
# 데이터 분석은 우리가 어떤 현상이나 문제를 더 잘 이해하기 위해 **데이터를 수집하고, 정리하고, 계산하고, 해석하는 과정**입니다.

# %% [markdown]
# ### ✔ 왜 배워야 할까?
# - 사회, 경제, 과학, 스포츠, 교육 등 모든 분야에서 데이터 기반 의사결정이 중요해졌어요.
# - 데이터를 잘 다루는 능력은 미래의 필수 역량입니다!

# %% [markdown]
# ## 📊 데이터 분석의 5단계
#
# | 단계 | 설명 |
# |------|------|
# | 1단계 | **데이터 수집**: 필요한 정보를 모은다 (설문, 센서, 웹 등) |
# | 2단계 | **데이터 정리/전처리**: 빠진 값, 이상치 제거 등 정리 작업 |
# | 3단계 | **데이터 분석**: 평균, 최대값, 상관관계 등 통계적 방법 사용 |
# | 4단계 | **데이터 시각화**: 그래프, 차트 등을 활용해 보기 쉽게 표현 |
# | 5단계 | **해석과 의사결정**: 결과를 통해 결론을 내리고 문제 해결 |

# %% [markdown]
# ## 🎥 동기부여 영상
# - [데이터로 세상을 보다 | 데이터 분석의 힘 (5분 영상)](https://youtu.be/aasrgF5LWdU?si=ItL5Pza-aaxuFo5O)
# - [빅데이터 전문가 송길영이 말하는 '빅데이터란 무엇인가?'](https://youtu.be/2A8NelGuWgI?si=WZdZlwskM5yJmyDl )

# %% [markdown]
# ## 📚 참고자료
# - 공공데이터포털: https://www.data.go.kr
# - Kaggle 데이터셋: https://www.kaggle.com/datasets

# %% [markdown]
# ## 📌 간단한 시각화 예시

# %% [markdown]
# ### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행 (코렙환경 설정)
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 글꼴 지정 명령어
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %% [markdown]
# 아래의 코드를 실행한 후 런타임 다시시작하기를 해준다.

# %%
# 한글 폰트 설정 <=실행하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumGothic')

years = [2020, 2021, 2022, 2023, 2024]
students = [23, 25, 21, 27, 26]

plt.plot(years, students, marker='o')
plt.title("우리 반 학생 수 변화")
plt.xlabel("연도")
plt.ylabel("학생 수")
plt.grid(True)
plt.show()

# %% [markdown]
# #데이터 분석을 위한 matplotlib(데이터 시각화) 라이브러리

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. matplotlib 라이브러리
#
# **다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리**
#
# > 파이썬에서 데이터를 차트(chart)나 플롯(Plot)으로 그려주는 라이브러리 패키지로서 가장 많이 사용되는 데이터 시각화 라이브러리입니다. </br>
#
# 공식 홈페이지 : https://matplotlib.org
#
# <그래프의 종류>
#
# - 라인 플롯(line plot)
# - 스캐터 플롯(scatter plot)
# - 컨투어 플롯(contour plot)
# - 서피스 플롯(surface plot)
# - 바 차트(bar chart)
# - 히스토그램(histogram)
# - 박스 플롯(box plot)
#
# </br>
# </br>
#
# <img src=https://grm-project-template-bucket.s3.ap-northeast-2.amazonaws.com/lesson/les_Zcgbt_1661411331314/8debf283a058efffed4559db052827f360a840e703f85c957b2de335504d74a0.png width=500>
#
# <img src='https://github.com/teacher-jiejie/allinone_AI/blob/images/80_%E1%84%85%E1%85%A1%E1%84%8B%E1%85%B5%E1%84%87%E1%85%B3%E1%84%85%E1%85%A5%E1%84%85%E1%85%B5.png?raw=true' width = 600>
#
# </br>
# </br>
# </br>
#
# > import 라이브러리명 as 닉네임</br>
#
# 닉네임.명령어A()</br>
# 닉네임.명령어B()</br>

# %% [markdown]
# ###파이썬 라이브러리
# https://docs.python.org/ko/3/library/index.html
#
# ###Matplotlob 라이브러리
# https://matplotlib.org/

# %% [markdown]
# matplotlib을 이용한 데이터 시각화 기본
#
#
# 아래는 그래프를 구성하는 주요 요소들의 명칭을 정리한 그림입니다.
#
# (출처 : matplotlib 공식페이지)
#
# <img src= https://grm-project-template-bucket.s3.ap-northeast-2.amazonaws.com/lesson/les_Zcgbt_1661411331314/f27af469f1d61a44157f8d5f20abce218336d769281799da1260bdb77aef8327.png width=500>

# %% [markdown]
# # Pyplot
#
# 맷플롯립 패키지에는 pyplot 라는 서브패키지가 존재합니다.
#
# Pyplot은 Matplotlib에서 그래프를 그리는 역할을 하는 모듈입니다.
#
# Pyplot을 이용해서 figure를 만들고, figure가 그려질 좌표를 만들고,
# 좌표에 몇 개의 선을 그리거나, 레이블을 붙이는 등의 작업이 가능합니다.
#
#
# Pyplot 서브패키지를 사용할 때에는 대개 plt 라는 별칭으로 불러와 사용합니다.

# %% [markdown]
# # Matplotlib을 활용한 데이터 시각화
#
# ## 🧭 수업 개요
# 이 단원에서는 **파이썬의 시각화 라이브러리인 `matplotlib`**를 활용하여 데이터를 시각적으로 표현하는 방법을 학습합니다.
# 시각화는 데이터를 더 쉽게 이해하고 전달하는 데 매우 중요한 도구입니다. 실제 데이터 분석 프로젝트에서 시각화는 빠질 수 없는 핵심 요소입니다.
#
# ---
#
# ## 🎯 학습 목표
# - `matplotlib.pyplot`의 기본 구조와 사용법을 이해할 수 있다.
# - 막대그래프, 선그래프, 산점도, 히스토그램 등 다양한 그래프를 그릴 수 있다.
# - 그래프에 제목, 축 레이블, 눈금, 범례 등을 추가하여 시각적인 완성도를 높일 수 있다.
# - 시각화를 통해 데이터의 패턴이나 인사이트를 도출할 수 있다.
#
# ---
#
# ## 🛠️ 준비 사항
# - Google Colab 환경에서 실습합니다.
# - 아래 명령어로 matplotlib을 설치할 수 있습니다. (Colab에는 기본 내장되어 있음)
#
# ```python
# !pip install matplotlib
# ```
#
# ---
#
# 이제 다양한 예제를 통해 matplotlib의 기본 사용법부터 실습해 봅시다!

# %% [markdown]
# ---
#
# ## 📝 실습 과제 및 프로젝트 아이디어
#
# ### 1️⃣ 기본 그래프 그리기 실습
# 다음 데이터를 사용하여 다양한 그래프를 직접 그려보세요.
#
# ```python
# x = [1, 2, 3, 4, 5]
# y = [10, 14, 12, 20, 18]
# ```
#
# - 막대그래프
# - 선그래프
# - 산점도
# - 히스토그램 (자유 데이터 활용)
#
# ---
#
# ### 2️⃣ 🎨 시각화 꾸미기 챌린지
# 아래 조건을 충족하도록 그래프를 꾸며보세요.
#
# - 제목(title) 추가
# - x축, y축 레이블 추가
# - 범례 추가
# - 색상 변경
# - 눈금 스타일 바꾸기
#
# ---
#
# ### 3️⃣ 📊 나만의 데이터 시각화 프로젝트
# 주제를 하나 정하고 데이터를 수집하거나 직접 만들어서 시각화해보세요.
# 예시 주제:
# - 학급 친구들의 아침 기상 시간 조사
# - 반 친구들의 좋아하는 과목 통계
# - 요일별 공부 시간 변화
#
# **Tip:** Google Forms나 직접 입력을 통해 데이터를 수집한 후 시각화하면 더욱 의미 있어요!
#
# ---
#
# ### 4️⃣ 🔍 오류 수정 디버깅 퀴즈
# 다음 코드에서 잘못된 부분을 찾아 수정해보세요.
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4]
# y = [10, 20, 15, 25]
#
# plt.bar(x, y)
# plt.title = "성장률 변화"
# plt.xlabel("년도")
# plt.ylabel("비율")
# plt.show()
# ```
#
# ---
#
# ### 5️⃣ 🧠 퀴즈: 어떤 그래프가 적절할까?
# 다음 데이터의 특징에 맞는 시각화 방법을 골라보세요.
# (선택지: 선그래프, 막대그래프, 히스토그램, 산점도)
#
# 1. 시간에 따른 온도 변화
# 2. 학생들의 시험 점수 분포
# 3. 과목별 평균 점수 비교
# 4. 키와 몸무게의 관계

# %% [markdown]
# ###꺽은선 그래프 그리기

# %%
#matplotlib 라이브러리에 속한 pyplot 모듈 불러오기
import matplotlib.pyplot

# %%
#라이브러리 닉네임 사용하기
import matplotlib.pyplot as plt

# %%
#꺾은선 그래프 그려보기
x=[1,2,3]
y=[2,4,8]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# plt.plot()은 matplotlib.pyplot.plot()와 같은 명령이다.
# >
# plot() 함수에 입력된 리스트는 y축 값으로 입력되며, x축을 생략할 경우 값이 자동으로 0부터 1씩 증가하는 정수로 입력된다.

# %%
# plot()함수에 두 개의 리스트 입력(x축, y축)
plt.plot([1, 2, 3, 4], [10, 30, 20, 40])
plt.show()

# %% [markdown]
# *주의 :
# x축 데이터와 y축 데이터의 개수가 맞지 않을 경우 에러가 발생함.

# %% [markdown]
# plot 함수를 사용하여 기본 그래프를 그리는 방법
# ```
# 1. 라이브러리 불러오기
# 2. plot()함수에 데이터 입력하기
# 3. 그래프 보여주기
#
# import matplotlib.pyplot as plt
# plt.plot([x축 데이터], [y축 데이터])
# plt.show()
# ```

# %% [markdown]
# 매출그래프 그리기
#
# ```
# 3-7월 매출
#
# 3월 = 10
# 4월 = 50
# 5월 = 70
# 6월 = 30
# 7월 = 70
# ```

# %% [markdown]
# ### 선 그래프 그리기

# %%
# 1. matplotlib 라이브러리 불러오기
import matplotlib.pyplot as plt

# 2. plot 함수에 3~7월 매출 데이터 넣기
plt.plot([3,4,5,6,7], [10,50,70,30,70])

# 3. 그래프 보여주기
plt.show()

# %%
# sales 리스트에 3~7월 매출 데이터 넣기
sales = [10,50,70,30,70]
# plot() 함수에 sales 리스트 넣기
plt.plot(sales)
# 그래프 보여주기
plt.show()

# %% [markdown]
# ### x축 추가하기
#
#
# ```
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
# mon리스트에 월 이름 데이터 넣기(mar, apr, may, jun, jul)
mon = ['mar','apr','may','jun','jul']

# sales리스트에 월별 매출 데이터 넣기
sales = [10,50,70,30,70]

# X축에 mon, y축에 sales 리스트 넣고 그래프 나타내기
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# # 2. 그래프 꾸미기

# %% [markdown]
# ### 그래프 제목 추가하기
#
#
# ```
# plt.title('제목')
# plt.plot(x축, y축)
# plt.show()
# ```

# %%
#그래프 제목 추가하기(영어로)
plt.title("monthly sales")
plt.plot(mon, sales)
plt.show()

# %%
#한글 제목 넣어보기
plt.title("월별 실적")
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# ### 코랩에서 한글 폰트 설정
# 1) 한글 폰트 코드 실행 (코렙환경 설정)
#
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```
#
# 2) 런타임 - 런타임 다시시작
#
# 3) 글꼴 지정 명령어
#
# ```
# plt.rc('font', family='NanumGothic')
# ```

# %% [markdown]
# 아래의 코드를 실행한 후 런타임 다시시작하기를 해준다.

# %%
# 한글 폰트 설정 <=실행하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# **런타임을 재실행했으므로 변수를 다시 만들어주고, 라이브러리를 다시 import 해야 함**
#
#
# ```
# import matplotlib.pyplot as plt
#
# mon = ['mar','apr','may','jun','jul']
# sales = [1,5,7,3,7]
#
# # 한글 폰트 설정
#
# plt.title('월별 판매 실적')
# plt.plot(mon, sales)
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

mon = ['mar','apr','may','jun','jul']
sales = [10,50,70,30,70]

#한글 폰트 설정(맥은 AppleGothic)
plt.rc('font', family='NanumGothic')

#한글 제목 입력
plt.title("월별 판매 실적")
# X축, y축 그래프에 나타내기
plt.plot(mon, sales)
plt.show()

# %% [markdown]
# 사용가능한 폰트 확인

# %%
#사용가능한 폰트 확인

import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeFiveSym',
#  'cmsy10',
#  'DejaVu Serif',
#  'cmtt10',
#  'DejaVu Sans',
#  'NanumBarunGothic',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'Liberation Serif',
#  'NanumMyeongjo',
#  'NanumBarunGothic',
#  'Liberation Sans',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'Liberation Mono',
# ...

# %% [markdown]
# ### 그래프 색상 변경
#
#
# ```
# # 그래프 그리는 명령어에 color 옵션 추가
# plt.plot(x축, y축, color = 'r')
# ```

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')

# 그래프 색상 변경(좋아하는 색으로 해보기)
plt.plot(mon, sales, color = "yellow")
plt.show()

# %% [markdown]
# <img src = 'https://github.com/teacher-jiejie/allinone_AI/blob/images/22_%EA%B7%B8%EB%9E%98%ED%94%84%20%EC%BB%AC%EB%9F%AC.png?raw=true' width = 500>

# %% [markdown]
# ### 해상도 설정 : 그래프를 선명하게
#
# ```
# plt.figure(dpi=해상도)
# plt.title('제목')
# plt.plot(x축, y축, color = '')
# plt.show()
# ```

# %%
# 해상도 설정
plt.figure(dpi=200)
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
plt.plot(mon, sales, color ='pink')
plt.show()

# %% [markdown]
# ### 범례 나타내기
# 범례는 보통 두 개 이상의 데이터를 표시할 때 사용됨
#
# ```
# plt.plot(x축, y축, label = '범례 내용')
# plt.legend()      # 범례를 화면에 나타내기
# plt.show()
# ```

# %%
plt.figure(dpi=100)
plt.title('월별 판매 실적')
# 범례 label
plt.plot(mon, sales, color = 'b', label="단위 개수")
# 범례를 화면에 나타내는 legend()
plt.legend()
plt.show()

# %% [markdown]
# 범례의 위치를 직접 지정하는 법
# ```
# plt.legend(loc = 5)  #오른쪽 중간
# ```
# ![범례.png](data:image/png;base64,...)

# %% [markdown]
# ## 그래프 그리는 포맷
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# plt.plot(x축 데이터, y축 데이터)
# plt.show()
# ```
#
# 그래프 명령어 plt.plot()에 사용가능한 옵션
#
# ```
# color = '색상이름'
# label = '범례내용'
# ```
#
# 기타 사용가능한 명령어
# ```
# plt.figure(dpi=150)     # 그래프 해상도 설정
# plt.legend()            # 범례 나타내기
# ```

# %% [markdown]
# # 3. 다양한 그래프
#  plt.bar(x축 리스트, y축 리스트) : 막대그래프 - 세로형

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
#세로형 막대그래프 나타내기
plt.bar(mon, sales)
plt.show()

# %%
#실행해보기
plt.bar(mon, sales)
plt.show()

# %% [markdown]
# plt.bar()는 x축 리스트, y축 리스트 두 개 모두 넣어야 한다.

# %% [markdown]
# ### range() 사용하기
# plt.bar(range(시작숫자, 종료숫자), x축)

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
# range() 사용하기
plt.bar(range(3,8), sales, color ='b')
plt.show()

# %% [markdown]
# ### range(시작숫자, 종료숫자, 간격)
#
# 시작숫자부터 종료숫자까지 간격을 두어 숫자를 선택함 <br/>
#
#
# ```
# range(2, 11, 2)
# ```
# 2부터 11까지 간격 2를 두고 숫자 선택
# -> 2, 4, 6, 8, 10

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
# range() 사용하기
plt.bar(range(2, 11, 2), sales, color ='b')
plt.show()

# %% [markdown]
# ### plt.barh() : 막대그래프 - 가로형

# %%
plt.rc('font', family='NanumGothic')
plt.title('월별 판매 실적')
# 막대그래프 가로형 나타내기
plt.barh(range(3, 8), sales, color = 'hotpink')
plt.show()

# %% [markdown]
# ### plt.hist() : 히스토그램

# %%
print(sales)
# Out:
# [10, 50, 70, 30, 70]

# %%
plt.rc('font', family='NanumGothic')
plt.title('판매 실적 히스토그램')
# 히스토그램 나타내기
plt.hist(sales)
plt.show()

# %% [markdown]
# ### plt.pie() : 원그래프
#
#
# ```
# 우리학교 100명의 혈액형을 조사한 결과가 다음과 같다.
#
# A형 = 28명
# B형 = 20명
# O형 = 40명
# AB형 = 12명
# ```

# %%
b_type = [28, 20, 40, 12]
#원그래프 나타내기
plt.pie(b_type)
plt.show()

# %% [markdown]
# #### 원그래프 각 항목에 라벨 붙이기
#
#
# ```
# plt.pie(리스트, labels = 라벨리스트)
# ```

# %%
b_type = [28, 20, 40, 12]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.rc('font', family='NanumGothic')
plt.title('혈액형 비율')
# 라벨 붙이기
plt.pie(b_type, labels= b_name)
plt.show()

# %% [markdown]
# #### 원그래프 항목에 퍼센트 표시
#
# ```
# plt.pie(리스트, labels = 라벨리스트, autopct = '%1.1f%%')
# ```

# %%
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']

plt.rc('font', family='NanumGothic')
plt.title('혈액형 비율')
#퍼센트 표시하기
plt.pie(b_type, labels = b_name, autopct = "%1.1f%%")
plt.show()

# %% [markdown]
# ### plt.scatter() : 산점도
#
# > 국어를 잘하는 친구가 영어도 잘할까?
#
#
# ```
# 국어점수와 영어점수의 상관관계 알아보기
#
# kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
# eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]
# ```

# %%
kor =[80, 20, 50, 20, 10, 50, 60, 30, 60]
eng =[90, 40, 60, 40, 10, 30, 50, 70, 90]

#산점도 그래프 그리기
plt.scatter(kor,eng)
plt.show()

# %% [markdown]
# <img src = 'https://github.com/teacher-jiejie/allinone_AI/blob/images/81_scatter.png?raw=true' width=800>

# %% [markdown]
# ### 그래프 꾸미기 : x축 이름, y축 이름 붙이기
#
#
# ```
# plt.xlabel('x축 이름')
# plt.ylabel('y축 이름')
# ```

# %%
plt.figure(dpi=100)
plt.rc('font', family='NanumGothic')
plt.title('국어점수와 영어점수와의 상관관계')
plt.scatter(kor, eng, c='indigo')
# x축 이름,  y축 이름 붙이기
plt.xlabel('국어점수')
plt.ylabel('영어점수')
plt.show()

# %%
#라벨 위치 변경
plt.scatter(kor, eng, c='indigo')
# x축 이름,  y축 이름 붙이기
plt.xlabel('국어점수', loc= "right")
plt.ylabel('영어점수', loc="top")
plt.show()

# %% [markdown]
# # 그래프 명령어 정리
# **그래프 그리는 포맷**
# ```
# import matplotlib.pyplot as plt
#
# plt.title('그래프 제목')
# # --- 그래프 형태에 따라 알맞은 명령어 넣기 ---
# plt.show()
# ```
#
#
# **그래프 유형별 명령어**
# ```
# # ---- 그래프 유형별 명령어
# # 꺾은선그래프
# plt.plot([x축 리스트], [y축 리스트])
#
# # 막대그래프 세로
# plt.bar([x축 리스트], [y축 리스트])
#
# # 막대그래프 가로
# plt.barh([x축 리스트], [y축 리스트])
#
# # 히스토그램 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.hist( [리스트], bins = 구간개수 )
#
# # 원 그래프 (x축, y축을 구분하지 않고 하나의 리스트만 넣음)
# plt.pie( [리스트], labels = [데이터 구간 이름])
#
# # 산점도
# plt.scatter([x축 리스트], [y축 리스트])
# ```
#
# **그래프 명령어 내에 추가 가능한 옵션**
#
# ```
# color = '색상이름'
# alpha = 투명도
#
# # plt.plot(), plt.bar(), plt.barh(), plt.scatter()는 label 사용
# label = '범례내용'
#
# # plt.pie(), plt.boxplot()은 labels 사용
# labels = [범례 리스트]
#
# # plt.pie()에 퍼센트 자동 표시
# autopct = ‘%1.1%%’
# ```
#
# **기타 사용가능한 명령어**
#
#
# ```
# plt.legend()            # 범례 나타내기
# plt.xlabel()            # x축 이름 붙이기
# plt.ylabel()            # y축 이름 붙이기
# ```

# %% [markdown]
# ---
#
# ## 📚 마무리 과제: 나만의 데이터 시각화 리포트 만들기
#
# 수업과 실습을 마친 후, 여러분만의 데이터 시각화 리포트를 작성해보세요!
# 아래 내용을 포함하면 좋아요 😊
#
# ---
#
# ### 📌 과제 주제 예시
# - 나의 하루 시간 사용 분석
# - 친구들에게 설문조사한 결과 시각화
# - 인터넷에서 찾은 공공데이터 시각화
#
# ---
#
# ### 📑 리포트에 포함해야 할 요소
# 1. **주제 설명** ✍️
#    어떤 데이터를 시각화했는지 간단히 설명해주세요.
#
# 2. **데이터 준비 과정** 📦
#    데이터를 어떻게 수집했는지, 어떤 형식인지 소개하세요.
#
# 3. **시각화 코드 및 결과** 📊
#    다양한 `matplotlib` 그래프를 활용하여 데이터를 표현해보세요.
#    - 선그래프 / 막대그래프 / 산점도 / 히스토그램 중 2가지 이상 사용
#
# 4. **시각화에 대한 해석** 🧐
#    그래프를 보고 어떤 인사이트를 얻을 수 있었는지 설명해보세요.
#
# ---
#
# ### 🧾  형식
# - 깔끔하게 정리된 마크다운 포함
# - 각 시각화에는 **제목/레이블/범례**를 반드시 포함해주세요!
#
# 열심히 실습한 내용을 바탕으로, 멋진 시각화 리포트를 만들어보세요! 🎉

# %% [markdown]
# 출력결과 그래프를 아래의 패들렛 링크에 공유해주세요.
#
# https://padlet.com/kis_mid_sw/6-2-h4ckgwz243izareg

# %%
#아래에 설명과 코드를 함께 작성하시오.
b_type = [25, 19, 37]
b_name = ['모르겠다', '맞는 것 같다', '아닌듯']

plt.rc('font', family='NanumGothic')
plt.title('탈모 비율')
#퍼센트 표시하기
plt.pie(b_type, labels = b_name, autopct = "%1.1f%%")
plt.show()
